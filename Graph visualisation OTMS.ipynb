# %%
import networkx as nx

G=nx.Graph()

# adding just one node:
G.add_node("a")
# a list of nodes:
G.add_nodes_from(["b","c"])

print("Nodes of graph: ")
print(G.nodes())
print("Edges of graph: ")
print(G.edges())
# Out:
# Nodes of graph:
# ['a', 'b', 'c']
# Edges of graph:
# []

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
 
# Build a dataframe with your connections
df = pd.DataFrame({ 'from':['A', 'B', 'C','A','C'], 'to':['D', 'A', 'E','C','B'], 'value':['typeA', 'typeA', 'typeB', 'typeB','typeA']})

 
# And I need to transform my categorical column in a numerical value typeA->1, typeB->2...
df['value']=pd.Categorical(df['value'])
df['value'].cat.codes
 
# Build your graph
G=nx.from_pandas_edgelist(df, 'from', 'to', create_using=nx.Graph() )
 
# Custom the nodes:
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_color=df['value'].cat.codes, width=10.0, edge_cmap=plt.cm.Set2)

# %%
# libraries
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
 
# Build a dataframe with your connections
df = pd.DataFrame({ 'from':['A', 'B', 'C','A'], 'to':['D', 'A', 'E','C'], 'value':[1, 10, 5, 5]})

 
# Build your graph
G=nx.from_pandas_edgelist(df, 'from', 'to', create_using=nx.Graph() )
 
# Custom the nodes:
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_color=df['value'], width=10.0, edge_cmap=plt.cm.Blues)
plt.savefig('C:/Users/user/Desktop/intern/edges.png')

# %%
# libraries
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Build a dataframe with your connections
#df = pd.DataFrame({ 'from':['A', 'B', 'C','A','Zebra','E'], 'to':['D', 'A', 'E','C','E','A'], 'value':[1, 10, 5, 5,7,4]})
df = pd.DataFrame({ 'from':['Achampet', 'Sarpavaram', 'Nagamalli','JNTUK'], 'to':['Sarpavaram', 'Nagamalli','JNTUK','Bhanugudi'], 'value':[1, 10, 5, 5]})


# Build your graph
G=nx.from_pandas_edgelist(df, 'from', 'to', create_using=nx.Graph() )

# Custom the nodes:
nx.draw_kamada_kawai(G, with_labels=True, node_color='skyblue', node_size=1500, edge_color=df['value'], width=10.0, edge_cmap=plt.cm.Blues)
plt.savefig('C:/Users/user/OTMS/edges.png')

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Build a dataframe with your connections
#df = pd.DataFrame({ 'from':['A', 'B', 'C','A','Zebra','E'], 'to':['D', 'A', 'E','C','E','A'], 'value':[1, 10, 5, 5,7,4]})
df = pd.DataFrame({ 'from':['ashram public school', 'sarpavaram to samalkot', 'sarpavaram to SRMT','Beach to srpvrm','SRMT TO Sarpvm','Sarpvm to SRMT','beach to srvp','SRMT to sarp','sarpvrm to SRMT','sarpvrm'], 'to':['sarpvrm to samalkot', 'sarpvrm to SRMT', 'beach to sarpvrm','SRMT to sarpvrm','sarpvrm to samalkot','nagamalli','godarigunta','atchanpet','Ashram school','BNST'], 'value':[1,2, 10, 5,4,12,3,7,5,9]})
df

# Build your graph
G=nx.from_pandas_edgelist(df, 'from', 'to', create_using=nx.Graph() )

# Custom the nodes:
nx.draw_kamada_kawai(G, with_labels=True, node_color='skyblue', node_size=1500, edge_color=df['value'], width=10.0, edge_cmap=plt.cm.Blues)
plt.savefig('C:/Users/user/OTMS/map.png')
